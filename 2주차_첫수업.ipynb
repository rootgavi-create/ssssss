# %% [markdown]
# <a href="https://colab.research.google.com/github/rootgavi-create/ssssss/blob/main/2%EC%A3%BC%EC%B0%A8_%EC%B2%AB%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 숫자 변수 만들기 (나이나 개수를 저장할 때 써요)
apple_count = 5  # 사과가 5개 있어요
my_age = 11      # 내 나이는 11살이에요

# 2. 스트링(글자) 변수 만들기 (이름이나 말을 저장할 때 써요)
# 글자를 쓸 때는 꼭 ' ' 또는 " " 따옴표로 감싸줘야 해요!
my_name = "김철수"
greeting = "만나서 반가워!"

# 3. 변수에 저장된 내용 출력하기
print("--- 내 소개 ---")
print("이름:", my_name)
print("나이:", my_age)
print("사과 개수:", apple_count)
print("인사말:", greeting)

# 4. 숫자 변수로 계산도 할 수 있어요!
total_apples = apple_count + 3
print("사과 3개를 더 받으면 총", total_apples, "개가 됩니다!")

# %%
import random

def guess_number_game():
    target_number = random.randint(1, 100)
    attempts = 0
    print("1부터 100 사이의 숫자를 맞춰보세요!")

    while True:
        try:
            user_guess = int(input("숫자를 입력하세요: "))
            attempts += 1

            if user_guess < target_number:
                print("더 큰 숫자입니다!")
            elif user_guess > target_number:
                print("더 작은 숫자입니다!")
            else:
                print(f"축하합니다! {attempts}번 만에 숫자를 맞췄습니다.")
                break
        except ValueError:
            print("유효한 숫자를 입력해주세요.")

guess_number_game()
# Out:
# 1부터 100 사이의 숫자를 맞춰보세요!
# 숫자를 입력하세요: 50
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 60
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 70
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 80
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 90
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 95
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 99
# 더 작은 숫자입니다!
# 숫자를 입력하세요: 98
# 더 작은 숫자입니다!
# 숫자를 입력하세요:
# 유효한 숫자를 입력해주세요.
# 숫자를 입력하세요: 7
# 더 큰 숫자입니다!
# 숫자를 입력하세요: 97
# 더 작은 숫자입니다!
# 숫자를 입력하세요: 96
# 축하합니다! 11번 만에 숫자를 맞췄습니다.

# %%
# 1. random (랜덤): 무작위로 숫자를 뽑는 마법이에요
import random
lucky_number = random.randint(1, 10) # 1~10 사이 중 하나를 뽑아요
print("오늘의 행운 숫자는?", lucky_number)

# 2. while (반복문): 정답을 맞힐 때까지 계속 반복해요
# 'True'라고 쓰면 '그만!'이라고 할 때까지 계속 실행돼요
print("\n--- 반복문 예시 ---")
count = 1
while count <= 3:
    print(count, "번 반복 중...")
    count = count + 1

# 3. input (입력): 사용자에게 직접 물어보고 대답을 들어요
# user_answer = input("좋아하는 과일은? ")
# print(user_answer, "를 좋아하시는군요!")

# 4. if / elif / else (조건문): 상황에 따라 다른 행동을 해요
print("\n--- 조건문 예시 ---")
my_score = 90
if my_score >= 90:
    print("최고예요! 뛰어난 실력이네요.")
elif my_score >= 50:
    print("잘하고 있어요!")
else:
    print("조금 더 힘내봐요!")

# 5. try / except (예외 처리): 숫자를 써야 하는데 글자를 썼을 때처럼 실수가 생겨도 프로그램이 멈추지 않게 도와줘요
print("\n--- 예외 처리 예시 ---")
try:
    number = int("글자") # 숫자가 아닌 것을 숫자로 바꾸려 하면 에러가 나요
except:
    print("에러가 발생했지만 프로그램은 멈추지 않고 이 문장을 출력해요!")
